# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../PRECO_MEDICAMENTO_GOV.csv', delimiter=';')

df = df.drop(index=df.index[:51])

df.head()
# Out:
# C:\Users\caio_\AppData\Local\Temp\ipykernel_9304\3229474440.py:1: DtypeWarning: Columns (3,5,13,14,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../PRECO_MEDICAMENTO_GOV.csv', delimiter=';')
#                Secretaria Executiva - CMED          Unnamed: 1  \
# 51                              SUBSTÂNCIA                CNPJ
# 52                                     NaN                 NaN
# 53  21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL  18.459.628/0001-15
# 54                              ABATACEPTE  56.998.982/0001-07
# 55                              ABATACEPTE  56.998.982/0001-07
#
#                                 Unnamed: 2       Unnamed: 3     Unnamed: 4  \
# 51                             LABORATÓRIO     CÓDIGO GGREM       REGISTRO
# 52                                     NaN              NaN            NaN
# 53                              BAYER S.A.  538912020009303  1705600230032
# ...

# %%
df.isnull().sum()
# Out:
# Secretaria Executiva - CMED        1
# Unnamed: 1                         1
# Unnamed: 2                         1
# Unnamed: 3                         1
# Unnamed: 4                         1
#                                ...
# Unnamed: 58                        1
# Unnamed: 59                    24430
# Unnamed: 60                        1
# Unnamed: 61                        1
# Unnamed: 62                        1
# Length: 63, dtype: int64
